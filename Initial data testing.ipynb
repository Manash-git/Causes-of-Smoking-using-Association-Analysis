# %%
print('OK')
# Out:
# OK

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_column',50)
pd.set_option('display.max_rows',20)

# %%
# Loading the dataset

data = pd.read_excel('Survey On Addiction with Smoking Responses.xlsx')

# %%
data.head()
# Out:
#   Your gender ? Do you smoke ?  \
# 0          Male             No
# 1          Male             No
# 2          Male            Yes
# 3          Male            Yes
# 4          Male             No
#
#   What was your age when you smoked for the first time ? (if you never smoked, then select present age.)  \
# 0                                              19-25
# 1                                              19-25
# 2                                              19-25
# 3                                              13-16
# 4                                              19-25
#
#   Personal/Psychological factors (if you are non-smoker , then choose present status) [How was your academic performance when you started smoking? (For non smoker give present performance)]  \
# 0                                          Very good
# 1                                          Very good
# 2                                          Very good
# ...

# %%
for i in data.columns:
    print('====> ',i)
# Out:
# ====>  Your gender ?
# ====>  Do you smoke ?
# ====>  What was your age when you smoked for the first time ? (if you never smoked, then select present age.)
# ====>  Personal/Psychological factors (if you are non-smoker , then choose present status) [How was your academic performance when you started smoking? (For non smoker give present performance)]
# ====>  Personal/Psychological factors (if you are non-smoker , then choose present status) [How was your relationship with your family when you started smoking? (For non smoker give present status)]
# ====>  Personal/Psychological factors (if you are non-smoker , then choose present status) [How was your attachment to school when you started smoking? (For non smoker give present status)]
# ====>  Personal/Psychological factors (if you are non-smoker , then choose present status) [How was your self-esteem level (আত্মমর্যাদাবোধ) when you started smoking? (For non smoker give present status)]
# ...

# %%
df_csv= pd.read_csv('A Survey On Addiction to Smoking.csv')
df_csv
# Out:
#     Your gender? Do you smoke?  \
# 0           Male           Yes
# 1           Male           Yes
# 2           Male           Yes
# 3         Female            No
# 4           Male            No
# ..           ...           ...
# 496         Male           Yes
# 497         Male            No
# 498       Female            No
# 499         Male           Yes
# 500         Male           Yes
#
#     What was your age when you smoked for the first time? (if you never smoked, then select the present age)  \
# 0                                                16-19
# 1                                                19-25
# 2                                                16-19
# 3                                                19-25
# 4                                                19-25
# ..                                                 ...
# 496                                              16-19
# 497                                              19-25
# ...

# %%
data['Do you smoke ?']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1003    Yes
# 1004     No
# 1005     No
# 1006    Yes
# 1007    Yes
# Name: Do you smoke ?, Length: 1008, dtype: object

# %%
data['Do you smoke ?']=='Yes'
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1003     True
# 1004    False
# 1005    False
# 1006     True
# 1007     True
# Name: Do you smoke ?, Length: 1008, dtype: bool

# %%
data_yes= data[data['Do you smoke ?']=='Yes']
data_yes
# Out:
#      Your gender ? Do you smoke ?  \
# 2             Male            Yes
# 3             Male            Yes
# 11            Male            Yes
# 13            Male            Yes
# 21            Male            Yes
# ...            ...            ...
# 998           Male            Yes
# 1001          Male            Yes
# 1003          Male            Yes
# 1006          Male            Yes
# 1007          Male            Yes
#
#      What was your age when you smoked for the first time ? (if you never smoked, then select present age.)  \
# 2                                                 19-25
# 3                                                 13-16
# 11                                                19-25
# 13                                                16-19
# 21                                                16-19
# ...                                                 ...
# 998                                               16-19
# ...

# %%
data_yes.values
# Out:
# array([['Male', 'Yes', '19-25', ..., 'Secondary', 'Watching TV/Cinema',
#         nan],
#        ['Male', 'Yes', '13-16', ..., 'Primary',
#         'Watching TV/Cinema, Peer influence, Family influence, To feel mature, Poor performance in class, To follow senior in locality, To attract girl, To attract boy',
#         nan],
#        ['Male', 'Yes', '19-25', ..., 'University', 'Peer influence', nan],
#        ...,
#        ['Male', 'Yes', '16-19', ..., 'College/university/tertiary',
#         'Secondary',
#         'Family influence;To feel mature;To follow senior in locality;To attract girl'],
#        ['Male', 'Yes', '19-25', ..., 'College/university/tertiary',
#         'Secondary',
#         'To feel mature;To follow senior in locality;To attract girl'],
#        ['Male', 'Yes', '16-19', ..., 'College/university/tertiary',
#         'Secondary',
#         'Watching TV/Cinema;Family influence;To feel mature;To follow senior in locality']],
#       dtype=object)

# %%
data_yes.isnull()
# Out:
#       Your gender ?  Do you smoke ?  \
# 2             False           False
# 3             False           False
# 11            False           False
# 13            False           False
# 21            False           False
# ...             ...             ...
# 998           False           False
# 1001          False           False
# 1003          False           False
# 1006          False           False
# 1007          False           False
#
#       What was your age when you smoked for the first time ? (if you never smoked, then select present age.)  \
# 2                                                 False
# 3                                                 False
# 11                                                False
# 13                                                False
# 21                                                False
# ...                                                 ...
# 998                                               False
# ...

# %%
data_yes.isnull().sum()
# Out:
# Your gender ?                                                                                                                                                                                       0
# Do you smoke ?                                                                                                                                                                                      0
# What was your age when you smoked for the first time ? (if you never smoked, then select present age.)                                                                                              0
# Personal/Psychological factors (if you are non-smoker , then choose present status) [How was your academic performance when you started smoking? (For non smoker give present performance)]         0
# Personal/Psychological factors (if you are non-smoker , then choose present status) [How was your relationship with your family when you started smoking? (For non smoker give present status)]     0
# ...
